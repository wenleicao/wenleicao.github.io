# %%
from sklearn.compose import make_column_selector, make_column_transformer, ColumnTransformer
from sklearn.pipeline import make_pipeline, Pipeline, FunctionTransformer, FeatureUnion, make_union
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.feature_selection import chi2,SelectKBest
import numpy as  np
import pandas as pd

# %%
df = pd.DataFrame(
        {
            'Name':['Trump', 'Swift', 'Wenlei'] ,   
            'Sex': ['M', 'F', 'M'],
            'Age':[80, 20, 50],
            'Motto':["Tariff is beautiful", "Be good to people", "Everyone should have a dream"]            

        }
)
df.head()
# Out:
#      Name Sex  Age                         Motto
# 0   Trump   M   80           Tariff is beautiful
# 1   Swift   F   20             Be good to people
# 2  Wenlei   M   50  Everyone should have a dream

# %%
#test create post ETL process function,  then num_pipeline(Age), cat_pipeline (Name, Sex), txt_pipeline(Motto)
def update_age(X,y=None):
    X['Age'] = X['Age'] + 1
    return X

#make it transformer

transformer_update_age = FunctionTransformer(update_age)

# %%
#test transformer
transformer_update_age.fit_transform(df)
# Out:
#      Name Sex  Age                         Motto
# 0   Trump   M   81           Tariff is beautiful
# 1   Swift   F   21             Be good to people
# 2  Wenlei   M   51  Everyone should have a dream

# %%
#define 
num_columns = ['Age']
cat_columns =['Name', "Sex"]
Txt_columns =['Motto']

# %%
#build each pipeline and test
num_pipeline = make_pipeline(  SimpleImputer(strategy='median'), StandardScaler())     
num_pipeline.fit_transform(df[num_columns])
# Out:
# array([[ 1.22474487],
#        [-1.22474487],
#        [ 0.        ]])

# %%
cat_pipeline = make_pipeline(SimpleImputer(strategy='constant', fill_value='Missing'), OneHotEncoder(handle_unknown='ignore'))
cat_pipeline.fit_transform(df[cat_columns])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 6 stored elements and shape (3, 5)>

# %%
#first check if it works if I do this
pipe1 = make_pipeline(transformer_update_age, make_column_transformer(
        (num_pipeline, num_columns),
        (cat_pipeline, cat_columns),
))

# %%
pipe1.fit_transform(df)
# Out:
# array([[ 1.22474487,  0.        ,  1.        ,  0.        ,  0.        ,
#          1.        ],
#        [-1.22474487,  1.        ,  0.        ,  0.        ,  1.        ,
#          0.        ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ,  0.        ,
#          1.        ]])

# %%
df.head()
# Out:
#      Name Sex  Age                         Motto
# 0   Trump   M   82           Tariff is beautiful
# 1   Swift   F   22             Be good to people
# 2  Wenlei   M   52  Everyone should have a dream

# %%
#sometime we need dynamic choose column, for example, when tuning the model, we might want to choose which column to use to flow downstream
#use index
pipe2 = make_pipeline(transformer_update_age, make_column_transformer(
        (num_pipeline, [2]),
        (cat_pipeline, [1]),
))
pipe2.fit_transform(df)

#use slice
pipe2 = make_pipeline(transformer_update_age, make_column_transformer(
        (num_pipeline, [2]),
        (cat_pipeline, slice(0,2)),
))
pipe2.fit_transform(df)

#use mask as a boolean list
cat_mask =  [  c for c in df.columns if c =='Name'] 
pipe2 = make_pipeline(transformer_update_age, make_column_transformer(
        (num_pipeline, [2]),
        (cat_pipeline, cat_mask),
))
pipe2.fit_transform(df)
#use name regex pattern
pipe2 = make_pipeline(transformer_update_age, make_column_transformer(
        (num_pipeline, [2]),
        (cat_pipeline, make_column_selector(pattern = 'N.*')),
))
pipe2.fit_transform(df)
#use datatype include, exclude 
pipe2 = make_pipeline(transformer_update_age, make_column_transformer(
        (num_pipeline, make_column_selector(dtype_include='number')),
        (cat_pipeline, cat_columns),
))
pipe2.fit_transform(df)
#exclude
pipe2 = make_pipeline(transformer_update_age, make_column_transformer(
        (num_pipeline, make_column_selector(dtype_exclude='object')),
        (cat_pipeline, cat_columns),
))
pipe2.fit_transform(df)
# Out:
# array([[ 1.22474487,  0.        ,  1.        ,  0.        ,  0.        ,
#          1.        ],
#        [-1.22474487,  1.        ,  0.        ,  0.        ,  1.        ,
#          0.        ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ,  0.        ,
#          1.        ]])

# %%
df['Motto'].to_numpy().reshape(-1, 1).ravel()
# Out:
# array(['Tariff is beautiful', 'Be good to people',
#        'Everyone should have a dream'], dtype=object)

# %%
#what if we add txt feature
#https://stackoverflow.com/questions/71805720/using-countvectorizer-with-pipeline-and-columntransformer-and-getting-attributee
txt1_pipeline =  make_pipeline ( 
                    SimpleImputer(strategy='constant', fill_value='Missing'),                   #title   
                    #CountVectorizer(),
                    # SelectKBest(chi2,k=5), 
                    # TfidfTransformer(use_idf=True)
                    )

txt1_pipeline.fit_transform(df['Motto'].to_frame())
# Out:
# array([['Tariff is beautiful'],
#        ['Be good to people'],
#        ['Everyone should have a dream']], dtype=object)

# %%
txt1_pipeline =  make_pipeline ( 
                    SimpleImputer(strategy='constant', fill_value='Missing'),                   #title   
                    CountVectorizer(),
                    # SelectKBest(chi2,k=5), 
                    # TfidfTransformer(use_idf=True)
                    )

txt1_pipeline.fit_transform(df['Motto'].to_frame())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 8
#       1 txt1_pipeline =  make_pipeline (
#       2                     SimpleImputer(strategy='constant', fill_value='Missing'),                   #title
#       3                     CountVectorizer(),
#       4                     # SelectKBest(chi2,k=5),
#       5                     # TfidfTransformer(use_idf=True)
#       6                     )
# ----> 8 txt1_pipeline.fit_transform(df['Motto'].to_frame())
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\pipeline.py:541, in Pipeline.fit_transform(self, X, y, **params)
#     539 last_step_params = routed_params[self.steps[-1][0]]
#     540 if hasattr(last_step, "fit_transform"):
# --> 541     return last_step.fit_transform(
#     542         Xt, y, **last_step_params["fit_transform"]
#     543     )
#     544 else:
#     545     return last_step.fit(Xt, y, **last_step_params["fit"]).transform(
#     546         Xt, **last_step_params["transform"]
#     547     )
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\feature_extraction\text.py:1372, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1364             warnings.warn(
#    1365                 "Upper case characters found in"
#    1366                 " vocabulary while 'lowercase'"
#    1367                 " is True. These entries will not"
#    1368                 " be matched with any documents"
#    1369             )
#    1370             break
# -> 1372 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1374 if self.binary:
#    1375     X.data.fill(1)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\feature_extraction\text.py:1259, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1257 for doc in raw_documents:
#    1258     feature_counter = {}
# -> 1259     for feature in analyze(doc):
#    1260         try:
#    1261             feature_idx = vocabulary[feature]
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\feature_extraction\text.py:108, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     106 else:
#     107     if preprocessor is not None:
# --> 108         doc = preprocessor(doc)
#     109     if tokenizer is not None:
#     110         doc = tokenizer(doc)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\feature_extraction\text.py:66, in _preprocess(doc, accent_function, lower)
#      47 """Chain together an optional series of text preprocessing steps to
#      48 apply to a document.
#      49
#    (...)
#      63     preprocessed string
#      64 """
#      65 if lower:
# ---> 66     doc = doc.lower()
#      67 if accent_function is not None:
#      68     doc = accent_function(doc)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'lower'

# %%
impute_result = SimpleImputer(strategy='constant', fill_value='Missing').fit_transform(df['Motto'].to_frame())
impute_result
# Out:
# array([['Tariff is beautiful'],
#        ['Be good to people'],
#        ['Everyone should have a dream']], dtype=object)

# %%
#https://stackoverflow.com/questions/26367075/countvectorizer-attributeerror-numpy-ndarray-object-has-no-attribute-lower
CountVectorizer().fit_transform(impute_result.ravel())
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 11 stored elements and shape (3, 11)>

# %%
#create 1DWrapper
class oneDwrapper ( BaseEstimator, TransformerMixin):
     #convert to 1d only one bracket#     
     def __init__(self, transformer):
        self.transformer = transformer

     def fit (self, X, y=None ):
         self.transformer.fit(X, y)
         return self
     
     def transform(self, X):
         return np.array(self.transformer.transform(X)).ravel()

# %%
txt1_pipeline =  make_pipeline ( 
                    oneDwrapper(SimpleImputer(strategy='constant', fill_value='Missing')),                   
                    CountVectorizer(),
                    # SelectKBest(chi2,k=5), 
                    # TfidfTransformer(use_idf=True)
                    )

txt1_pipeline.fit_transform(df['Motto'].to_frame())
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 11 stored elements and shape (3, 11)>

# %%
print(txt1_pipeline.fit_transform(df['Motto'].to_frame()))
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 11 stored elements and shape (3, 11)>
#   Coords	Values
#   (0, 9)	1
#   (0, 6)	1
#   (0, 1)	1
#   (1, 0)	1
#   (1, 4)	1
#   (1, 10)	1
#   (1, 7)	1
#   (2, 3)	1
#   (2, 8)	1
#   (2, 5)	1
#   (2, 2)	1

# %%
#https://github.com/scikit-learn/scikit-learn/issues/28791 
txt1_pipeline =  make_pipeline ( 
                    oneDwrapper(SimpleImputer(strategy='constant', fill_value='Missing')),                   #title   
                    CountVectorizer(),
                    SelectKBest(chi2,k=5), 
                    
                    )

txt1_pipeline.fit_transform(df['Motto'].to_frame(), y=[1, 2, 3])  #chi2 need y, I put abitary y value here
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 5 stored elements and shape (3, 5)>

# %%
txt1_pipeline =  make_pipeline ( 
                    oneDwrapper(SimpleImputer(strategy='constant', fill_value='Missing')),                   #title   
                    CountVectorizer(),
                    SelectKBest(chi2,k=5), 
                    TfidfTransformer(use_idf=True)
                    )

txt1_pipeline.fit_transform(df['Motto'].to_frame(), y=[1, 2, 3])    #single pipeline work, it also take df, then convert to single array in oneDwrapper
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 5 stored elements and shape (3, 5)>

# %%
#put together with other component
#make pipeline with txt_pipe
pipe3 = make_pipeline(transformer_update_age, make_column_transformer(
        (num_pipeline, num_columns),
        (cat_pipeline, cat_columns),
        (txt1_pipeline, Txt_columns)
))
pipe3.fit_transform(df, [1, 2, 3])  #[1, 2, 3] simulated y, which required when training
# Out:
# array([[ 1.22474487,  0.        ,  1.        ,  0.        ,  0.        ,
#          1.        ,  0.70710678,  0.        ,  0.        ,  0.70710678,
#          0.        ],
#        [-1.22474487,  1.        ,  0.        ,  0.        ,  1.        ,
#          0.        ,  0.        ,  0.70710678,  0.        ,  0.        ,
#          0.70710678],
#        [ 0.        ,  0.        ,  0.        ,  1.        ,  0.        ,
#          1.        ,  0.        ,  0.        ,  1.        ,  0.        ,
#          0.        ]])

# %%
#now by default, transform output is array, what impact would be if I turn the deault to pandas
#change global 
from sklearn import set_config
set_config(transform_output="pandas")
pipe3.fit_transform(df, [1, 2, 3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 5
#       3 from sklearn import set_config
#       4 set_config(transform_output="pandas")
# ----> 5 pipe3.fit_transform(df, [1, 2, 3])
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\pipeline.py:541, in Pipeline.fit_transform(self, X, y, **params)
#     539 last_step_params = routed_params[self.steps[-1][0]]
#     540 if hasattr(last_step, "fit_transform"):
# --> 541     return last_step.fit_transform(
#     542         Xt, y, **last_step_params["fit_transform"]
#     543     )
#     544 else:
#     545     return last_step.fit(Xt, y, **last_step_params["fit"]).transform(
#     546         Xt, **last_step_params["transform"]
#     547     )
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\compose\_column_transformer.py:976, in ColumnTransformer.fit_transform(self, X, y, **params)
#     973 else:
#     974     routed_params = self._get_empty_routing()
# --> 976 result = self._call_func_on_transformers(
#     977     X,
#     978     y,
#     979     _fit_transform_one,
#     980     column_as_labels=False,
#     981     routed_params=routed_params,
#     982 )
#     984 if not result:
#     985     self._update_fitted_transformers([])
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\compose\_column_transformer.py:885, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     873             extra_args = {}
#     874         jobs.append(
#     875             delayed(func)(
#     876                 transformer=clone(trans) if not fitted else trans,
#    (...)
#     882             )
#     883         )
# --> 885     return Parallel(n_jobs=self.n_jobs)(jobs)
#     887 except ValueError as e:
#     888     if "Expected 2D array, got 1D array instead" in str(e):
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\pipeline.py:1310, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1308 with _print_elapsed_time(message_clsname, message):
#    1309     if hasattr(transformer, "fit_transform"):
# -> 1310         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1311     else:
#    1312         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1313             X, **params.get("transform", {})
#    1314         )
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\pipeline.py:541, in Pipeline.fit_transform(self, X, y, **params)
#     539 last_step_params = routed_params[self.steps[-1][0]]
#     540 if hasattr(last_step, "fit_transform"):
# --> 541     return last_step.fit_transform(
#     542         Xt, y, **last_step_params["fit_transform"]
#     543     )
#     544 else:
#     545     return last_step.fit(Xt, y, **last_step_params["fit"]).transform(
#     546         Xt, **last_step_params["transform"]
#     547     )
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\base.py:1101, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
# -> 1101     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\preprocessing\_encoders.py:1012, in OneHotEncoder.transform(self, X)
#    1010 if transform_output != "default" and self.sparse_output:
#    1011     capitalize_transform_output = transform_output.capitalize()
# -> 1012     raise ValueError(
#    1013         f"{capitalize_transform_output} output does not support sparse data."
#    1014         f" Set sparse_output=False to output {transform_output} dataframes or"
#    1015         f" disable {capitalize_transform_output} output via"
#    1016         '` ohe.set_output(transform="default").'
#    1017     )
#    1019 # validation of X happens in _check_X called by _transform
#    1020 warn_on_unknown = self.drop is not None and self.handle_unknown in {
#    1021     "ignore",
#    1022     "infrequent_if_exist",
#    1023 }
#
# ValueError: Pandas output does not support sparse data. Set sparse_output=False to output pandas dataframes or disable Pandas output via` ohe.set_output(transform="default").

# %%
#what if I change onehot encode to dense
cat_pipeline1 = make_pipeline(SimpleImputer(strategy='constant', fill_value='Missing'), 
                             OneHotEncoder(handle_unknown='ignore', sparse_output=False))
pipe4 = make_pipeline(transformer_update_age, make_column_transformer(
        (num_pipeline, num_columns),
        (cat_pipeline1, cat_columns),
        (txt1_pipeline, Txt_columns)
))
pipe4.fit_transform(df, [1, 2, 3])  #[1, 2, 3] simulated y, which required when training
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 9
#       2 cat_pipeline1 = make_pipeline(SimpleImputer(strategy='constant', fill_value='Missing'),
#       3                              OneHotEncoder(handle_unknown='ignore', sparse_output=False))
#       4 pipe4 = make_pipeline(transformer_update_age, make_column_transformer(
#       5         (num_pipeline, num_columns),
#       6         (cat_pipeline1, cat_columns),
#       7         (txt1_pipeline, Txt_columns)
#       8 ))
# ----> 9 pipe4.fit_transform(df, [1, 2, 3])  #[1, 2, 3] simulated y, which required when training
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\pipeline.py:541, in Pipeline.fit_transform(self, X, y, **params)
#     539 last_step_params = routed_params[self.steps[-1][0]]
#     540 if hasattr(last_step, "fit_transform"):
# --> 541     return last_step.fit_transform(
#     542         Xt, y, **last_step_params["fit_transform"]
#     543     )
#     544 else:
#     545     return last_step.fit(Xt, y, **last_step_params["fit"]).transform(
#     546         Xt, **last_step_params["transform"]
#     547     )
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\compose\_column_transformer.py:976, in ColumnTransformer.fit_transform(self, X, y, **params)
#     973 else:
#     974     routed_params = self._get_empty_routing()
# --> 976 result = self._call_func_on_transformers(
#     977     X,
#     978     y,
#     979     _fit_transform_one,
#     980     column_as_labels=False,
#     981     routed_params=routed_params,
#     982 )
#     984 if not result:
#     985     self._update_fitted_transformers([])
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\compose\_column_transformer.py:885, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     873             extra_args = {}
#     874         jobs.append(
#     875             delayed(func)(
#     876                 transformer=clone(trans) if not fitted else trans,
#    (...)
#     882             )
#     883         )
# --> 885     return Parallel(n_jobs=self.n_jobs)(jobs)
#     887 except ValueError as e:
#     888     if "Expected 2D array, got 1D array instead" in str(e):
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\pipeline.py:1310, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1308 with _print_elapsed_time(message_clsname, message):
#    1309     if hasattr(transformer, "fit_transform"):
# -> 1310         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1311     else:
#    1312         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1313             X, **params.get("transform", {})
#    1314         )
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\pipeline.py:533, in Pipeline.fit_transform(self, X, y, **params)
#     490 """Fit the model and transform with the final estimator.
#     491
#     492 Fit all the transformers one after the other and sequentially transform
#    (...)
#     530     Transformed samples.
#     531 """
#     532 routed_params = self._check_method_params(method="fit_transform", props=params)
# --> 533 Xt = self._fit(X, y, routed_params)
#     535 last_step = self._final_estimator
#     536 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\pipeline.py:406, in Pipeline._fit(self, X, y, routed_params)
#     404     cloned_transformer = clone(transformer)
#     405 # Fit or load from cache the current transformer
# --> 406 X, fitted_transformer = fit_transform_one_cached(
#     407     cloned_transformer,
#     408     X,
#     409     y,
#     410     None,
#     411     message_clsname="Pipeline",
#     412     message=self._log_message(step_idx),
#     413     params=routed_params[name],
#     414 )
#     415 # Replace the transformer of the step with the fitted
#     416 # transformer. This is necessary when loading the transformer
#     417 # from the cache.
#     418 self.steps[step_idx] = (name, fitted_transformer)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\joblib\memory.py:312, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     311 def __call__(self, *args, **kwargs):
# --> 312     return self.func(*args, **kwargs)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\pipeline.py:1310, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1308 with _print_elapsed_time(message_clsname, message):
#    1309     if hasattr(transformer, "fit_transform"):
# -> 1310         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1311     else:
#    1312         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1313             X, **params.get("transform", {})
#    1314         )
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\base.py:1101, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
# -> 1101     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\utils\_set_output.py:326, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     323         return type(data_to_wrap)._make(return_tuple)
#     324     return return_tuple
# --> 326 return _wrap_data_with_container(method, data_to_wrap, X, self)
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\utils\_set_output.py:294, in _wrap_data_with_container(method, data_to_wrap, original_input, estimator)
#     292 dense_config = output_config["dense"]
#     293 if issparse(data_to_wrap):
# --> 294     raise ValueError(
#     295         "The transformer outputs a scipy sparse matrix. "
#     296         "Try to set the transformer output to a dense array or disable "
#     297         f"{dense_config.capitalize()} output with set_output(transform='default')."
#     298     )
#     300 adapter = ADAPTERS_MANAGER.adapters[dense_config]
#     301 return adapter.create_container(
#     302     data_to_wrap,
#     303     original_input,
#     304     columns=estimator.get_feature_names_out,
#     305 )
#
# ValueError: The transformer outputs a scipy sparse matrix. Try to set the transformer output to a dense array or disable Pandas output with set_output(transform='default').

# %%
#looks it is also from txt_pipeline, since it is not easily changable, I will keep use default format
#the good about use pandas format is quick way to retrieve the input feature name
#assume pipeline end is clf, use clf[-1].feature_names_in_

# %%
#convert back to default
set_config(transform_output="default")
pipe3.fit_transform(df, [1, 2, 3])
# Out:
# array([[ 1.22474487,  0.        ,  1.        ,  0.        ,  0.        ,
#          1.        ,  0.70710678,  0.        ,  0.        ,  0.70710678,
#          0.        ],
#        [-1.22474487,  1.        ,  0.        ,  0.        ,  1.        ,
#          0.        ,  0.        ,  0.70710678,  0.        ,  0.        ,
#          0.70710678],
#        [ 0.        ,  0.        ,  0.        ,  1.        ,  0.        ,
#          1.        ,  0.        ,  0.        ,  1.        ,  0.        ,
#          0.        ]])

# %%
#pipe3 structure
pipe3
# Out:
# Pipeline(steps=[('functiontransformer',
#                  FunctionTransformer(func=<function update_age at 0x000002248F29FCE0>)),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['Age']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(f...
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Name', 'Sex']),
#                                                  ('pipeline-3',
#                                                   Pipeline(steps=[('onedwrapper',
#                                                                    oneDwrapper(transformer=SimpleImputer(fill_value='Missing',
#                                                                                                          strategy='constant'))),
#                                                                   ('countvectorizer',
#                                                                    CountVectorizer()),
#                                                                   ('selectkbest',
#                                                                    SelectKBest(k=5,
#                                                                                score_func=<function chi2 at 0x00000224907996C0>)),
#                                                                   ('tfidftransformer',
#                                                                    TfidfTransformer())]),
#                                                   ['Motto'])]))])

# %%
pipe3[-1].feature_names_in_
# Out:
# array(['Name', 'Sex', 'Age', 'Motto'], dtype=object)

# %%
#how to retrieve featur name
pipe3.get_feature_names_out()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 2
#       1 #how to retrieve featur name
# ----> 2 pipe3.get_feature_names_out()
#
# File c:\Users\wenle\miniconda3\envs\sklearn\Lib\site-packages\sklearn\pipeline.py:1069, in Pipeline.get_feature_names_out(self, input_features)
#    1067 for _, name, transform in self._iter():
#    1068     if not hasattr(transform, "get_feature_names_out"):
# -> 1069         raise AttributeError(
#    1070             "Estimator {} does not provide get_feature_names_out. "
#    1071             "Did you mean to call pipeline[:-1].get_feature_names_out"
#    1072             "()?".format(name)
#    1073         )
#    1074     feature_names_out = transform.get_feature_names_out(feature_names_out)
#    1075 return feature_names_out
#
# AttributeError: Estimator functiontransformer does not provide get_feature_names_out. Did you mean to call pipeline[:-1].get_feature_names_out()?

# %%
print({k:v for k, v in pipe3.named_steps.items()})
# Out:
# {'functiontransformer': FunctionTransformer(func=<function update_age at 0x000002248F29FCE0>), 'columntransformer': ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Age']),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='Missing',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['Name', 'Sex']),
#                                 ('pipeline-3',
#                                  Pipeline(steps=[('onedwrapper',
#                                                   oneDwrapper(transformer=SimpleImputer(fill_value='Missing',
#                                                                                         strategy='constant'))),
#                                                  ('countvectorizer',
#                                                   CountVectorizer()),
#                                                  ('selectkbest',
#                                                   SelectKBest(k=5,
#                                                               score_func=<function chi2 at 0x00000224907996C0>)),
#                                                  ('tfidftransformer',
#                                                   TfidfTransformer())]),
#                                  ['Motto'])])}

# %%
#https://stackoverflow.com/questions/54646709/sklearn-pipeline-get-feature-names-after-onehotencode-in-columntransformer
pipe3.named_steps['columntransformer']
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['Age']),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='Missing',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['Name', 'Sex']),
#                                 ('pipeline-3',
#                                  Pipeline(steps=[('onedwrapper',
#                                                   oneDwrapper(transformer=SimpleImputer(fill_value='Missing',
#                                                                                         strategy='constant'))),
#                                                  ('countvectorizer',
#                                                   CountVectorizer()),
#                                                  ('selectkbest',
#                                                   SelectKBest(k=5,
#                                                               score_func=<function chi2 at 0x00000224907996C0>)),
#                                                  ('tfidftransformer',
#                                                   TfidfTransformer())]),
#                                  ['Motto'])])

# %%
pipe3.named_steps['columntransformer'].get_params()
# Out:
# {'force_int_remainder_cols': True,
#  'n_jobs': None,
#  'remainder': 'drop',
#  'sparse_threshold': 0.3,
#  'transformer_weights': None,
#  'transformers': [('pipeline-1',
#    Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                    ('standardscaler', StandardScaler())]),
#    ['Age']),
#   ('pipeline-2',
#    Pipeline(steps=[('simpleimputer',
#                     SimpleImputer(fill_value='Missing', strategy='constant')),
#                    ('onehotencoder', OneHotEncoder(handle_unknown='ignore'))]),
#    ['Name', 'Sex']),
#   ('pipeline-3',
#    Pipeline(steps=[('onedwrapper',
#                     oneDwrapper(transformer=SimpleImputer(fill_value='Missing',
#                                                           strategy='constant'))),
#                    ('countvectorizer', CountVectorizer()),
#                    ('selectkbest',
#                     SelectKBest(k=5,
#                                 score_func=<function chi2 at 0x00000224907996C0>)),
#                    ('tfidftransformer', TfidfTransformer())]),
#    ['Motto'])],
#  'verbose': False,
#  'verbose_feature_names_out': True,
#  'pipeline-1': Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                  ('standardscaler', StandardScaler())]),
#  'pipeline-2': Pipeline(steps=[('simpleimputer',
#                   SimpleImputer(fill_value='Missing', strategy='constant')),
#                  ('onehotencoder', OneHotEncoder(handle_unknown='ignore'))]),
#  'pipeline-3': Pipeline(steps=[('onedwrapper',
#                   oneDwrapper(transformer=SimpleImputer(fill_value='Missing',
#                                                         strategy='constant'))),
#                  ('countvectorizer', CountVectorizer()),
#                  ('selectkbest',
#                   SelectKBest(k=5,
#                               score_func=<function chi2 at 0x00000224907996C0>)),
#                  ('tfidftransformer', TfidfTransformer())]),
#  'pipeline-1__memory': None,
#  'pipeline-1__steps': [('simpleimputer', SimpleImputer(strategy='median')),
#   ('standardscaler', StandardScaler())],
#  'pipeline-1__verbose': False,
#  'pipeline-1__simpleimputer': SimpleImputer(strategy='median'),
#  'pipeline-1__standardscaler': StandardScaler(),
#  'pipeline-1__simpleimputer__add_indicator': False,
#  'pipeline-1__simpleimputer__copy': True,
#  'pipeline-1__simpleimputer__fill_value': None,
#  'pipeline-1__simpleimputer__keep_empty_features': False,
#  'pipeline-1__simpleimputer__missing_values': nan,
#  'pipeline-1__simpleimputer__strategy': 'median',
#  'pipeline-1__standardscaler__copy': True,
#  'pipeline-1__standardscaler__with_mean': True,
#  'pipeline-1__standardscaler__with_std': True,
#  'pipeline-2__memory': None,
#  'pipeline-2__steps': [('simpleimputer',
#    SimpleImputer(fill_value='Missing', strategy='constant')),
#   ('onehotencoder', OneHotEncoder(handle_unknown='ignore'))],
#  'pipeline-2__verbose': False,
#  'pipeline-2__simpleimputer': SimpleImputer(fill_value='Missing', strategy='constant'),
#  'pipeline-2__onehotencoder': OneHotEncoder(handle_unknown='ignore'),
#  'pipeline-2__simpleimputer__add_indicator': False,
#  'pipeline-2__simpleimputer__copy': True,
#  'pipeline-2__simpleimputer__fill_value': 'Missing',
#  'pipeline-2__simpleimputer__keep_empty_features': False,
#  'pipeline-2__simpleimputer__missing_values': nan,
#  'pipeline-2__simpleimputer__strategy': 'constant',
#  'pipeline-2__onehotencoder__categories': 'auto',
#  'pipeline-2__onehotencoder__drop': None,
#  'pipeline-2__onehotencoder__dtype': numpy.float64,
#  'pipeline-2__onehotencoder__feature_name_combiner': 'concat',
#  'pipeline-2__onehotencoder__handle_unknown': 'ignore',
#  'pipeline-2__onehotencoder__max_categories': None,
#  'pipeline-2__onehotencoder__min_frequency': None,
#  'pipeline-2__onehotencoder__sparse_output': True,
#  'pipeline-3__memory': None,
#  'pipeline-3__steps': [('onedwrapper',
#    oneDwrapper(transformer=SimpleImputer(fill_value='Missing',
#                                          strategy='constant'))),
#   ('countvectorizer', CountVectorizer()),
#   ('selectkbest',
#    SelectKBest(k=5, score_func=<function chi2 at 0x00000224907996C0>)),
#   ('tfidftransformer', TfidfTransformer())],
#  'pipeline-3__verbose': False,
#  'pipeline-3__onedwrapper': oneDwrapper(transformer=SimpleImputer(fill_value='Missing',
#                                        strategy='constant')),
#  'pipeline-3__countvectorizer': CountVectorizer(),
#  'pipeline-3__selectkbest': SelectKBest(k=5, score_func=<function chi2 at 0x00000224907996C0>),
#  'pipeline-3__tfidftransformer': TfidfTransformer(),
#  'pipeline-3__onedwrapper__transformer__add_indicator': False,
#  'pipeline-3__onedwrapper__transformer__copy': True,
#  'pipeline-3__onedwrapper__transformer__fill_value': 'Missing',
#  'pipeline-3__onedwrapper__transformer__keep_empty_features': False,
#  'pipeline-3__onedwrapper__transformer__missing_values': nan,
#  'pipeline-3__onedwrapper__transformer__strategy': 'constant',
#  'pipeline-3__onedwrapper__transformer': SimpleImputer(fill_value='Missing', strategy='constant'),
#  'pipeline-3__countvectorizer__analyzer': 'word',
#  'pipeline-3__countvectorizer__binary': False,
#  'pipeline-3__countvectorizer__decode_error': 'strict',
#  'pipeline-3__countvectorizer__dtype': numpy.int64,
#  'pipeline-3__countvectorizer__encoding': 'utf-8',
#  'pipeline-3__countvectorizer__input': 'content',
#  'pipeline-3__countvectorizer__lowercase': True,
#  'pipeline-3__countvectorizer__max_df': 1.0,
#  'pipeline-3__countvectorizer__max_features': None,
#  'pipeline-3__countvectorizer__min_df': 1,
#  'pipeline-3__countvectorizer__ngram_range': (1, 1),
#  'pipeline-3__countvectorizer__preprocessor': None,
#  'pipeline-3__countvectorizer__stop_words': None,
#  'pipeline-3__countvectorizer__strip_accents': None,
#  'pipeline-3__countvectorizer__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'pipeline-3__countvectorizer__tokenizer': None,
#  'pipeline-3__countvectorizer__vocabulary': None,
#  'pipeline-3__selectkbest__k': 5,
#  'pipeline-3__selectkbest__score_func': <function sklearn.feature_selection._univariate_selection.chi2(X, y)>,
#  'pipeline-3__tfidftransformer__norm': 'l2',
#  'pipeline-3__tfidftransformer__smooth_idf': True,
#  'pipeline-3__tfidftransformer__sublinear_tf': False,
#  'pipeline-3__tfidftransformer__use_idf': True}

# %%
pipe3.named_steps['columntransformer'].named_transformers_['pipeline-1']
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler())])

# %%
pipe3.named_steps['columntransformer'].named_transformers_['pipeline-1'].named_steps['simpleimputer'].get_feature_names_out()
# Out:
# array(['Age'], dtype=object)

# %%
pipe3.named_steps['columntransformer'].named_transformers_['pipeline-3']
# Out:
# Pipeline(steps=[('onedwrapper',
#                  oneDwrapper(transformer=SimpleImputer(fill_value='Missing',
#                                                        strategy='constant'))),
#                 ('countvectorizer', CountVectorizer()),
#                 ('selectkbest',
#                  SelectKBest(k=5,
#                              score_func=<function chi2 at 0x00000224907996C0>)),
#                 ('tfidftransformer', TfidfTransformer())])

# %%
pipe3.named_steps['columntransformer'].named_transformers_['pipeline-3'].get_params()
# Out:
# {'memory': None,
#  'steps': [('onedwrapper',
#    oneDwrapper(transformer=SimpleImputer(fill_value='Missing',
#                                          strategy='constant'))),
#   ('countvectorizer', CountVectorizer()),
#   ('selectkbest',
#    SelectKBest(k=5, score_func=<function chi2 at 0x00000224907996C0>)),
#   ('tfidftransformer', TfidfTransformer())],
#  'verbose': False,
#  'onedwrapper': oneDwrapper(transformer=SimpleImputer(fill_value='Missing',
#                                        strategy='constant')),
#  'countvectorizer': CountVectorizer(),
#  'selectkbest': SelectKBest(k=5, score_func=<function chi2 at 0x00000224907996C0>),
#  'tfidftransformer': TfidfTransformer(),
#  'onedwrapper__transformer__add_indicator': False,
#  'onedwrapper__transformer__copy': True,
#  'onedwrapper__transformer__fill_value': 'Missing',
#  'onedwrapper__transformer__keep_empty_features': False,
#  'onedwrapper__transformer__missing_values': nan,
#  'onedwrapper__transformer__strategy': 'constant',
#  'onedwrapper__transformer': SimpleImputer(fill_value='Missing', strategy='constant'),
#  'countvectorizer__analyzer': 'word',
#  'countvectorizer__binary': False,
#  'countvectorizer__decode_error': 'strict',
#  'countvectorizer__dtype': numpy.int64,
#  'countvectorizer__encoding': 'utf-8',
#  'countvectorizer__input': 'content',
#  'countvectorizer__lowercase': True,
#  'countvectorizer__max_df': 1.0,
#  'countvectorizer__max_features': None,
#  'countvectorizer__min_df': 1,
#  'countvectorizer__ngram_range': (1, 1),
#  'countvectorizer__preprocessor': None,
#  'countvectorizer__stop_words': None,
#  'countvectorizer__strip_accents': None,
#  'countvectorizer__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'countvectorizer__tokenizer': None,
#  'countvectorizer__vocabulary': None,
#  'selectkbest__k': 5,
#  'selectkbest__score_func': <function sklearn.feature_selection._univariate_selection.chi2(X, y)>,
#  'tfidftransformer__norm': 'l2',
#  'tfidftransformer__smooth_idf': True,
#  'tfidftransformer__sublinear_tf': False,
#  'tfidftransformer__use_idf': True}

# %%
pipe3.named_steps['columntransformer'].named_transformers_['pipeline-3'].named_steps['selectkbest']
# Out:
# SelectKBest(k=5, score_func=<function chi2 at 0x00000224907996C0>)

# %%
pipe3.named_steps['columntransformer'].named_transformers_['pipeline-3'].named_steps['selectkbest'].get_feature_names_out()
# Out:
# array(['x6', 'x7', 'x8', 'x9', 'x10'], dtype=object)

# %%
pipe3.named_steps['columntransformer'].named_transformers_['pipeline-3'].named_steps['tfidftransformer'].get_feature_names_out()
# Out:
# array(['x0', 'x1', 'x2', 'x3', 'x4'], dtype=object)

# %%
class ExcludeColumnSelector(BaseEstimator, TransformerMixin):
    '''select specific columns of a given dataset
    
    num_pipeline = make_pipeline (
    ExcludeColumnSelector(oh_columns),
    SimpleImputer(strategy="median"),    
    Pipeline_winsorize(), #powertransform()
    StandardScaler())

    oh_pipeline = make_pipeline(
        IncludeColumnSelector(oh_columns),
        SimpleImputer(strategy="median"),
    )

    preprocessor = make_union (num_pipeline, oh_pipeline)
        
    '''
    def __init__(self, subset):
        self.subset = subset
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        return X.loc[:, ~X.columns.isin(self.subset)]
    

class IncludeColumnSelector(BaseEstimator, TransformerMixin):
    '''select specific columns of a given dataset'''
    def __init__(self, subset):
        self.subset = subset
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        #check if X contain the column in subset 
        column_list = [ i for i in X.columns if i in self.subset]
        return X.loc[:, column_list]

# %%
#more complicated senarior, first select text column use make uniono

txt_pipeline2 = make_pipeline(IncludeColumnSelector(['Motto']), txt1_pipeline)
txt_pipeline2
# Out:
# Pipeline(steps=[('includecolumnselector',
#                  IncludeColumnSelector(subset=['Motto'])),
#                 ('pipeline',
#                  Pipeline(steps=[('onedwrapper',
#                                   oneDwrapper(transformer=SimpleImputer(fill_value='Missing',
#                                                                         strategy='constant'))),
#                                  ('countvectorizer', CountVectorizer()),
#                                  ('selectkbest',
#                                   SelectKBest(k=5,
#                                               score_func=<function chi2 at 0x00000224907996C0>)),
#                                  ('tfidftransformer', TfidfTransformer())]))])

# %%
non_txt_pipeline2 = make_pipeline(ExcludeColumnSelector(['Motto']), make_column_transformer((num_pipeline, num_columns),(cat_pipeline, cat_columns)))
non_txt_pipeline2
# Out:
# Pipeline(steps=[('excludecolumnselector',
#                  ExcludeColumnSelector(subset=['Motto'])),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['Age']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(fill_value='Missing',
#                                                                                  strategy='constant')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Name', 'Sex'])]))])

# %%
#combine_all
pipe_all = make_pipeline(transformer_update_age, make_union(txt_pipeline2, non_txt_pipeline2))
pipe_all
# Out:
# Pipeline(steps=[('functiontransformer',
#                  FunctionTransformer(func=<function update_age at 0x000002248F29FCE0>)),
#                 ('featureunion',
#                  FeatureUnion(transformer_list=[('pipeline-1',
#                                                  Pipeline(steps=[('includecolumnselector',
#                                                                   IncludeColumnSelector(subset=['Motto'])),
#                                                                  ('pipeline',
#                                                                   Pipeline(steps=[('onedwrapper',
#                                                                                    oneDwrapper(transformer=SimpleImputer(fill_value='Missing...
#                                                                  ('columntransformer',
#                                                                   ColumnTransformer(transformers=[('pipeline-1',
#                                                                                                    Pipeline(steps=[('simpleimputer',
#                                                                                                                     SimpleImputer(strategy='median')),
#                                                                                                                    ('standardscaler',
#                                                                                                                     StandardScaler())]),
#                                                                                                    ['Age']),
#                                                                                                   ('pipeline-2',
#                                                                                                    Pipeline(steps=[('simpleimputer',
#                                                                                                                     SimpleImputer(fill_value='Missing',
#                                                                                                                                   strategy='constant')),
#                                                                                                                    ('onehotencoder',
#                                                                                                                     OneHotEncoder(handle_unknown='ignore'))]),
#                                                                                                    ['Name',
#                                                                                                     'Sex'])]))]))]))])

# %%
pipe_all.fit_transform(df, [1, 2, 3])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 13 stored elements and shape (3, 11)>
